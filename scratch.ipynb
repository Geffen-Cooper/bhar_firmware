# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.array([1873,1874,1874,1871,1869,1870,1924,1985,2097,2185,2270,2160,2275,2424,2549,2691,2742,2739,2736,2732,2738,2740,2735])
pwr = np.array([1,-1,0,0,-1,-1,19,42,89,127,165,96,123,147,172,208,285,232,161,97,25,-1,-2,-6,-2])
plt.scatter(np.arange(len(arr))*100,arr/10)
plt.plot(np.arange(len(arr))*100,arr/10)

plt.scatter(np.arange(len(pwr))*100,pwr)
plt.plot(np.arange(len(pwr))*100,pwr)
plt.grid()
